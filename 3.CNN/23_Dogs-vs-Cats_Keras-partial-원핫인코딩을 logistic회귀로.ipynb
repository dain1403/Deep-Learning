# %% [markdown]
# # Dogs vs Cats v3
# ## Kaggle Dataset의 일부를 이용한 개, 고양이 구분
# ### Dog Image: 1,111개, Cat Image: 1,111개, 총 2,222개
# ### one-hot encoding --> Logistic회귀
# - one hot encoding삭제, model에서 마지막 dense에서 1과 sigmoid로 변경, compile에서 binary-crossentropy 변경
#
# ### 출처: [pontoregende GitHub](https://github.com/pontorezende/Dogs-vs-Cats-Redux-with-CNN)

# %%
import numpy as np   
from glob import glob
import cv2, os, random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
# seed 값 설정
seed = 2020
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
path='dogs-vs-cats/train/'

# %% [markdown]
# ##### Train set 만들기

# %%
## used for resize and in our model
ROW, COL = 96, 96

dogs, cats = [], []
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'dog.5*')
len(glob(dog_path))
# Out:
# 1111

# %%
## Load some our dog images (1,111 개 이미지)
dog_path = os.path.join(path, 'dog.5*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
## Load some our cat images (1,111 개 이미지)
cat_path = os.path.join(path, 'cat.5*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
classes = ['dog', 'cat']

# %%
plt.figure(figsize=(12,8))    
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(dogs))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[0]))        
plt.show()

# %%
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(cats))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[1]))
plt.show()

# %%
## just change the labels for 0 and  1
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
y_dogs[:5]
# Out:
# [1, 1, 1, 1, 1]

# %%
y_dogs[0], y_cats[0]
# Out:
# (1, 0)

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
X_train = np.concatenate((dogs,cats), axis=0)
y_train = np.concatenate((y_dogs, y_cats), axis=0)

# %%
X_train.shape, y_train.shape
# Out:
# ((2222, 96, 96, 1), (2222,))

# %% [markdown]
# ###### Test set (dog.12*, cat12* ) 만들기

# %%
ROW, COL = 96, 96

dogs, cats = [], []
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'dog.12*')
len(glob(dog_path))
# Out:
# 611

# %%
## Load some our dog images (611 개 이미지)
dog_path = os.path.join(path, 'dog.12*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
## Load some our cat images (611 개 이미지)
cat_path = os.path.join(path, 'cat.12*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
## just change the labels for 0 and  1
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
dogs.shape
# Out:
# (611, 96, 96, 1)

# %%
X_test = np.concatenate((dogs,cats), axis=0)
y_test = np.concatenate((y_dogs, y_cats), axis=0)

# %%
len(X_test)
# Out:
# 1222

# %% [markdown]
# ###### 모델 설정

# %%
## Here is our model as a CNN
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(ROW, COL, 1), 
           activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(.5),
    Dense(1, activation='sigmoid')    ##변경
])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 96, 96, 32)        320
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 96, 96, 32)        9248
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 48, 48, 32)        0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 48, 48, 64)        18496
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 48, 48, 64)        36928
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 24, 24, 64)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 36864)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               18874880
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 18,940,385
# Trainable params: 18,940,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',            ##변경
              optimizer=Adam(), metrics=['accuracy'])

# %%
## to save checkpoint to use later
modelpath = "model/dogs_vs_cats-cnn3-{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# %% [markdown]
# ##### 모델 학습

# %%
X_train.shape
# Out:
# (2222, 96, 96, 1)

# %%
y_train.shape
# Out:
# (2222,)

# %%
model.fit(X_train, y_train, batch_size=32, epochs=40, validation_split=0.2, shuffle=True,
          callbacks=[checkpointer])  ## early_stopping_callback 배제시킴
# Out:
# Train on 1777 samples, validate on 445 samples
# Epoch 1/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.7224 - accuracy: 0.6091
# Epoch 00001: val_loss improved from inf to 0.90156, saving model to model/dogs_vs_cats-cnn3-01-0.9016.hdf5
# 1777/1777 [==============================] - 30s 17ms/sample - loss: 0.7219 - accuracy: 0.6095 - val_loss: 0.9016 - val_accuracy: 0.0000e+00
# Epoch 2/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6590 - accuracy: 0.6256
# Epoch 00002: val_loss improved from 0.90156 to 0.88524, saving model to model/dogs_vs_cats-cnn3-02-0.8852.hdf5
# 1777/1777 [==============================] - 29s 17ms/sample - loss: 0.6592 - accuracy: 0.6252 - val_loss: 0.8852 - val_accuracy: 0.0000e+00
# Epoch 3/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6481 - accuracy: 0.6335
# Epoch 00003: val_loss did not improve from 0.88524
# 1777/1777 [==============================] - 28s 15ms/sample - loss: 0.6482 - accuracy: 0.6331 - val_loss: 0.9434 - val_accuracy: 0.2045
# Epoch 4/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6304 - accuracy: 0.6602
# Epoch 00004: val_loss did not improve from 0.88524
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.6313 - accuracy: 0.6601 - val_loss: 1.0394 - val_accuracy: 0.1685
# Epoch 5/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6388 - accuracy: 0.6574
# Epoch 00005: val_loss improved from 0.88524 to 0.75184, saving model to model/dogs_vs_cats-cnn3-05-0.7518.hdf5
# 1777/1777 [==============================] - 30s 17ms/sample - loss: 0.6391 - accuracy: 0.6590 - val_loss: 0.7518 - val_accuracy: 0.3146
# Epoch 6/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6096 - accuracy: 0.6756
# Epoch 00006: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.6116 - accuracy: 0.6753 - val_loss: 1.3556 - val_accuracy: 0.1933
# Epoch 7/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.5786 - accuracy: 0.7028
# Epoch 00007: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.5776 - accuracy: 0.7046 - val_loss: 0.8850 - val_accuracy: 0.4135
# Epoch 8/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.5442 - accuracy: 0.7261
# Epoch 00008: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.5435 - accuracy: 0.7271 - val_loss: 0.8243 - val_accuracy: 0.3955
# Epoch 9/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.4904 - accuracy: 0.7597
# Epoch 00009: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.4893 - accuracy: 0.7603 - val_loss: 0.9070 - val_accuracy: 0.3753
# Epoch 10/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.4251 - accuracy: 0.7989
# Epoch 00010: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.4257 - accuracy: 0.7980 - val_loss: 0.8202 - val_accuracy: 0.5124
# Epoch 11/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.3723 - accuracy: 0.8341
# Epoch 00011: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.3711 - accuracy: 0.8351 - val_loss: 1.0831 - val_accuracy: 0.5011
# Epoch 12/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.2748 - accuracy: 0.8767
# Epoch 00012: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.2789 - accuracy: 0.8745 - val_loss: 1.3291 - val_accuracy: 0.4921
# Epoch 13/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.2403 - accuracy: 0.9017
# Epoch 00013: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.2403 - accuracy: 0.9015 - val_loss: 1.4250 - val_accuracy: 0.5303
# Epoch 14/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1729 - accuracy: 0.9278
# Epoch 00014: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.1747 - accuracy: 0.9268 - val_loss: 0.9722 - val_accuracy: 0.6539
# Epoch 15/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1156 - accuracy: 0.9545
# Epoch 00015: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.1150 - accuracy: 0.9550 - val_loss: 1.4282 - val_accuracy: 0.6067
# Epoch 16/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0930 - accuracy: 0.9653
# Epoch 00016: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0947 - accuracy: 0.9645 - val_loss: 2.0287 - val_accuracy: 0.5461
# Epoch 17/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0716 - accuracy: 0.9699
# Epoch 00017: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0721 - accuracy: 0.9696 - val_loss: 1.4940 - val_accuracy: 0.6337
# Epoch 18/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0699 - accuracy: 0.9733
# Epoch 00018: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0695 - accuracy: 0.9736 - val_loss: 1.6519 - val_accuracy: 0.6022
# Epoch 19/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0611 - accuracy: 0.9812
# Epoch 00019: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0606 - accuracy: 0.9814 - val_loss: 1.8792 - val_accuracy: 0.6135
# Epoch 20/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0368 - accuracy: 0.9892
# Epoch 00020: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0366 - accuracy: 0.9893 - val_loss: 2.8111 - val_accuracy: 0.5281
# Epoch 21/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0344 - accuracy: 0.9903
# Epoch 00021: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0342 - accuracy: 0.9904 - val_loss: 2.7671 - val_accuracy: 0.5393
# Epoch 22/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0264 - accuracy: 0.9932
# Epoch 00022: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0262 - accuracy: 0.9932 - val_loss: 2.3770 - val_accuracy: 0.5820
# Epoch 23/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0456 - accuracy: 0.9903
# Epoch 00023: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0452 - accuracy: 0.9904 - val_loss: 2.5115 - val_accuracy: 0.5506
# Epoch 24/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0240 - accuracy: 0.9937
# Epoch 00024: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0238 - accuracy: 0.9938 - val_loss: 2.8795 - val_accuracy: 0.5303
# Epoch 25/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0262 - accuracy: 0.9932
# Epoch 00025: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0260 - accuracy: 0.9932 - val_loss: 2.8189 - val_accuracy: 0.5326
# Epoch 26/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0189 - accuracy: 0.9943
# Epoch 00026: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0187 - accuracy: 0.9944 - val_loss: 2.1897 - val_accuracy: 0.6292
# Epoch 27/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0232 - accuracy: 0.9903
# Epoch 00027: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0231 - accuracy: 0.9904 - val_loss: 2.9634 - val_accuracy: 0.5685
# Epoch 28/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0100 - accuracy: 0.9972
# Epoch 00028: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0099 - accuracy: 0.9972 - val_loss: 3.2927 - val_accuracy: 0.5618
# Epoch 29/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0133 - accuracy: 0.9960
# Epoch 00029: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0132 - accuracy: 0.9961 - val_loss: 3.3391 - val_accuracy: 0.5101
# Epoch 30/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0117 - accuracy: 0.9955
# Epoch 00030: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0116 - accuracy: 0.9955 - val_loss: 3.1678 - val_accuracy: 0.5483
# Epoch 31/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0137 - accuracy: 0.9977
# Epoch 00031: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0136 - accuracy: 0.9977 - val_loss: 3.8836 - val_accuracy: 0.5124
# Epoch 32/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0241 - accuracy: 0.9920
# Epoch 00032: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0252 - accuracy: 0.9916 - val_loss: 2.8912 - val_accuracy: 0.5618
# Epoch 33/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9909
# Epoch 00033: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0319 - accuracy: 0.9904 - val_loss: 2.2311 - val_accuracy: 0.6247
# Epoch 34/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0266 - accuracy: 0.9932
# Epoch 00034: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0265 - accuracy: 0.9932 - val_loss: 2.1550 - val_accuracy: 0.6180
# Epoch 35/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0081 - accuracy: 0.9977
# Epoch 00035: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0081 - accuracy: 0.9977 - val_loss: 2.4478 - val_accuracy: 0.6045
# Epoch 36/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0071 - accuracy: 0.9977
# Epoch 00036: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0070 - accuracy: 0.9977 - val_loss: 3.1639 - val_accuracy: 0.5573
# Epoch 37/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0153 - accuracy: 0.9960
# Epoch 00037: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0151 - accuracy: 0.9961 - val_loss: 3.5501 - val_accuracy: 0.5326
# Epoch 38/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0392 - accuracy: 0.9875
# Epoch 00038: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0388 - accuracy: 0.9876 - val_loss: 3.4495 - val_accuracy: 0.5371
# Epoch 39/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0135 - accuracy: 0.9937
# Epoch 00039: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0134 - accuracy: 0.9938 - val_loss: 3.3939 - val_accuracy: 0.5281
# Epoch 40/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0164 - accuracy: 0.9949
# Epoch 00040: val_loss did not improve from 0.75184
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0163 - accuracy: 0.9949 - val_loss: 3.9112 - val_accuracy: 0.4966

# %%
from tensorflow.keras.models import load_model
del model
model = load_model('model/dogs_vs_cats-cnn-05-0.7518.hdf5')

# %%
scores = model.evaluate(X_test, y_test, verbose=2)
print('MODEL ACCURACY: %.5f' % scores[1])
# Out:
# 1222/1222 - 4s - loss: 0.6871 - accuracy: 0.5663
# MODEL ACCURACY: 0.56628
